# %% [markdown]
# # Dictionary

# %% [markdown]
# - values can be any type
# - multiple keys can have the same value
# - keys must be unique
# - keys don’t need to be string

# %%
# dictionary using constructor method
student = dict({
    "name":"ram",
    "country":"Nepal",
    "age":18,
    "name":"kamal"          })
print(student)
# Out:
# {'name': 'kamal', 'country': 'Nepal', 'age': 18}

# %%
type(student)
# Out:
# dict

# %%
# create a dictionary from sequence having each item as a pair
# dictionary using constructor method
student = dict({
    "name":"ram",
    "country":"Nepal",
    "age":18,
    "name":"kamal",
    "courses": ["dsml", "ai", "database"]})
print(student)
# Out:
# {'name': 'kamal', 'country': 'Nepal', 'age': 18, 'courses': ['dsml', 'ai', 'database']}

# %%
# create a dictionary from sequence having each item as a pair
# dictionary using constructor method
student = dict([ ("name","ram"),
    ("country","Nepal"),
    ("age",18),
    ("name","kamal"),
    ("courses", ["dsml", "ai", "database"])
   ])
print(student)
# Out:
# {'name': 'kamal', 'country': 'Nepal', 'age': 18, 'courses': ['dsml', 'ai', 'database']}

# %%
# creating dictionary with mixed keys
sample_dict = {
    "name":"gita",
    14:"TV"
}

# %%
print(sample_dict)
# Out:
# {'name': 'gita', 14: 'TV'}

# %%
type(sample_dict)
# Out:
# dict

# %%
type("name")
# Out:
# str

# %%
type(14)
# Out:
# int

# %%
type(sample_dict["name"])
# Out:
# str

# %%
# create dictionary with values"
person = {"name": "sita", "telephone":[9818740098, 9819190045, 9812347509]}

# %%
print(person)
# Out:
# {'name': 'sita', 'telephone': [9818740098, 9819190045, 9812347509]}

# %%
print(person["telephone"])
# Out:
# [9818740098, 9819190045, 9812347509]

# %%
student = dict([ ("name","ram"),
    ("country","Nepal"),
    ("age",18),
    ("name","kamal"),
    ("courses", ["dsml", "ai", "database"])
   ])
print(student)
# Out:
# {'name': 'kamal', 'country': 'Nepal', 'age': 18, 'courses': ['dsml', 'ai', 'database']}

# %%
print(student['age'])
# Out:
# 18

# %%
student.get('name')
# Out:
# 'kamal'

# %%
# Change a dictionary value (existing value) by using its key and assinging a new value.
student = {
    "name":"ram",
    "age": 18,
           }
student["age"] = 20
print(student)
# Out:
# {'name': 'ram', 'age': 20}

# %%
 # Dictionary method
student = dict([ ("name","ram"),
    ("country","Nepal"),
    ("age",18),
    ("name","kamal"),
    ("courses", ["dsml", "ai", "database"])
   ])
print(student)
# Out:
# {'name': 'kamal', 'country': 'Nepal', 'age': 18, 'courses': ['dsml', 'ai', 'database']}

# %%
# Print keys only
print(student.keys())
# Out:
# dict_keys(['name', 'country', 'age', 'courses'])

# %%
# Print values only
print(student.values())
# Out:
# dict_values(['kamal', 'Nepal', 18, ['dsml', 'ai', 'database']])

# %%
# print key:pair enclosed with braces
print(student.items())
# Out:
# dict_items([('name', 'kamal'), ('country', 'Nepal'), ('age', 18), ('courses', ['dsml', 'ai', 'database'])])

# %%
# Removing a single key:pair by indicating key
print(student.pop("name"))
# Out:
# kamal

# %%
print(student)
# Out:
# {'country': 'Nepal', 'age': 18, 'courses': ['dsml', 'ai', 'database']}

# %%
print(student.pop("country"))
# Out:
# Nepal

# %%
# not in dictionary passing message
student.pop("country", "not found")
# Out:
# 'not found'

# %%
student.pop("name", "error")
# Out:
# 'error'

# %%
print(student)
# Out:
# {'age': 18, 'courses': ['dsml', 'ai', 'database']}

# %%
student.popitem()
# Out:
# ('courses', ['dsml', 'ai', 'database'])

# %%
del student["age"]

# %%
 # Dictionary method
student = dict([ ("name","ram"),
    ("country","Nepal"),
    ("age",18),
    ("name","kamal"),
    ("courses", ["dsml", "ai", "database"])
   ])
print(student)
# Out:
# {'name': 'kamal', 'country': 'Nepal', 'age': 18, 'courses': ['dsml', 'ai', 'database']}

# %%
# removing the data from the dictionary
student.clear()

# %%
# if run this, NameError: name 'student' is not defined
del(student) # removing the dictionary

# %%
# What is the differences between pop in list or tuple and pip in dictionary?
list = [ 1, 2, 3, 4, 5]
list.pop()
# Out:
# 5

# %% [markdown]
# ***Removes the key-value pair
# Does NOT return the
# removed value
# Raises KeyError if key does
# not exist
# del data["phone"]
# pop()
# Removes the key-value
# pair
# Returns the removed
# value
# Can provide a default
# value to avoid errors
# data.pop("phone"
# ,
# "Not
# Found")
# data = {
# "name": "Dhiraj"
# ,
# "age": 22
# }
# Examples
# person = {'name': 'hari'
# ,
# 'country': 'USA'
# ,
# 'telephone': 1178,
# 'weight': 50,
# 'height': 6***

# %%
 # Dictionary method
student = dict([ ("name","ram"),
    ("country","Nepal"),
    ("age",18),
    ("name","kamal"),
    ("courses", ["dsml", "ai", "database"])
   ])
print(student)
# Out:
# {'name': 'kamal', 'country': 'Nepal', 'age': 18, 'courses': ['dsml', 'ai', 'database']}

# %%
student.pop("name")
# Out:
# 'Jiwan'

# %%
# Removes last inserted item from the dictionary
student1 = dict([ ("name","ram"),
    ("country","Nepal"),
    ("age",18),
    ("name","kamana"),
    ("courses", ["dsml", "ai", "database"])
   ])
print(student1)
# Out:
# {'name': 'kamana', 'country': 'Nepal', 'age': 18, 'courses': ['dsml', 'ai', 'database']}

# %%
# Removes last inserted item from the dictionary
student2 = dict([ ("name","shyam"),
    ("country","USA"),
    ("age",20),
    ("name","rabi"),
    ("courses", ["dsml","ml" "ai", "database"])
   ])
print(student2)
# Out:
# {'name': 'rabi', 'country': 'USA', 'age': 20, 'courses': ['dsml', 'mlai', 'database']}

# %%
student1.update(student2)

# %%
print(student1)
# Out:
# {'name': 'rabi', 'country': 'USA', 'age': 20, 'courses': ['dsml', 'mlai', 'database']}

# %%
# Removes last inserted item from the dictionary
student2 = dict([ ("name","shyam"),
    ("country","USA"),
    ("age",20),
    ("name","rabi"),
    ("courses", ["dsml","ml" "ai", "database"])
   ])
print(student2)
# Out:
# {'name': 'rabi', 'country': 'USA', 'age': 20, 'courses': ['dsml', 'mlai', 'database']}

# %%
# Removes last inserted item from the dictionary
student2 = dict([ ("name","shyam"),
    ("country","USA"),
    ("age",20),
    ("name","rabi"),
    ("courses", ["dsml","ml" "ai", "database"])
   ])
print(student2)
# Out:
# {'name': 'rabi', 'country': 'USA', 'age': 20, 'courses': ['dsml', 'mlai', 'database']}

# %%
student1.update(student2)

# %%
# overwrite

# %%
# Removes last inserted item from the dictionary
student1 = dict([ ("name","yam"),
    ("country","UK"),
    ("age",20),
    ("courses", [ "ai", "database"])
   ])
print(student2)
# Out:
# {'name': 'rabi', 'country': 'USA', 'age': 20, 'courses': ['dsml', 'mlai', 'database']}

# %%
# Removes last inserted item from the dictionary
student2 = dict([ ("name","John"),
    ("country","USA"),
    ("age",30),
    ("courses", ["dsml","ml" ])
   ])
print(student2)
# Out:
# {'name': 'John', 'country': 'USA', 'age': 30, 'courses': ['dsml', 'ml']}

# %%
# Removes last inserted item from the dictionary
student3 = dict([ ("name","shyam"),
    ("country","India"),
    ("age",20),
    ("courses", [ "database"])
   ])
print(student2)
# Out:
# {'name': 'John', 'country': 'USA', 'age': 30, 'courses': ['dsml', 'ml']}

# %%
# Removes last inserted item from the dictionary
student4 = dict([ ("name","shyam"),
    ("country","USA"),
    ("age",20),
    ("name","rabi"),
    ("courses", ["dsml","ml" "ai", "database"])
   ])
print(student4)
# Out:
# {'name': 'rabi', 'country': 'USA', 'age': 20, 'courses': ['dsml', 'mlai', 'database']}

# %%
student_dict = {**student1, **student2, **student3, **student4}

# %%
print(student_dict)
# Out:
# {'name': 'rabi', 'country': 'USA', 'age': 20, 'courses': ['dsml', 'mlai', 'database']}

# %%
# sorted
result = sorted(student_dict)

# %%
print(result)
# Out:
# ['age', 'country', 'courses', 'name']

# %%
student0 = {
    "a":2,
    "c": 3,
    "f":9
}

# %%
result = sorted(student0)

# %%
print(result)
# Out:
# ['a', 'c', 'f']

# %%
dict1 = {
    "a": 4,
    "c": 9
}

# %%
dict2 = {
    "z": 9,
    "y": 10
}

# %%
len(dict2)
# Out:
# 2

# %%
dict1 | dict2
# Out:
# {'a': 4, 'c': 9, 'z': 9, 'y': 10}

# %%
# Dictionary operations
dict({
    "a": 10,
    "b":20
})
# Out:
# {'a': 10, 'b': 20}

# %%
# empty dictionary
d2 = {}

# %%
# Set default
student4 = dict([ ("name","shyam"),
    ("country","USA"),
    ("age",20),
    ("courses", ["dsml","ml" "ai", "database"])
   ])
print(student4)
# Out:
# {'name': 'shyam', 'country': 'USA', 'age': 20, 'courses': ['dsml', 'mlai', 'database']}

# %%
student4.setdefault("name", "set as defaul")
# Out:
# 'shyam'

# %%
# Set default is used when there is no key set the defult value and used in error handling case
student6 = dict([ ("name","shyam"),
    ("country","USA"),
    ("age",20),
    ("courses", ["dsml","ml" "ai", "database"])
   ])
print(student4)
# Out:
# {'name': 'shyam', 'country': 'USA', 'age': 20, 'courses': ['dsml', 'mlai', 'database']}

# %%
student6.setdefault("name", "set as defaul")
# Out:
# 'shyam'

# %%
d2 = student6.copy()

# %%
print(d2)
# Out:
# {'name': 'shyam', 'country': 'USA', 'age': 20, 'courses': ['dsml', 'mlai', 'database']}

# %%
# max(d2)
print(max(d2))
# Out:
# name

# %%
print(min(d2))
# Out:
# age

# %%
print(d2)
# Out:
# {'name': 'shyam', 'country': 'USA', 'age': 20, 'courses': ['dsml', 'mlai', 'database']}

# %%
"keys_is_or_not" in d2.keys()
# Out:
# False

# %%
print(d2)
# Out:
# {'name': 'shyam', 'country': 'USA', 'age': 20, 'courses': ['dsml', 'mlai', 'database']}

# %%
d2.keys()
# Out:
# dict_keys(['name', 'country', 'age', 'courses'])

# %% [markdown]
# # Class task

# %% [markdown]
# ***Q.N.1. Create a dictionary to store student name, age, and faculty.***

# %%
student = {
    "name":"Jiwan",
    "age": 10,
    "faculty": "Science and Tecnology"
}

# %%
#  2. adding
student["phone"] = 9818009734
student["city"] = "kathmandu"

# %%
student.update()

# %%
print(student)
# Out:
# {'name': 'Jiwan', 'age': 10, 'faculty': 'Science and Tecnology', 'phone': 9818009734, 'city': 'kathmandu'}

# %%
# Remove
del student["city"]

# %%
print(student)
# Out:
# {'name': 'Jiwan', 'age': 10, 'faculty': 'Science and Tecnology', 'phone': 9818009734}

# %%
# check
student.setdefault("email", "not exist")
# Out:
# 'not exist'
